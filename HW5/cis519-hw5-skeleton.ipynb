# %%
import torch
import torchvision

import torch.utils.tensorboard as tb

from PIL import Image

from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

import matplotlib.pyplot as plt
import pandas as pd

LABEL_NAMES = {'background':0, 'kart':1, 'pickup':2, 'nitro':3, 'bomb':4, 'projectile':5}

LABEL_=['background','kart','pickup','nitro','bomb','projectile']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c65209496a43> in <module>
# ----> 1 import torch
#       2 import torchvision
#       3
#       4 import torch.utils.tensorboard as tb
#       5
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## Reading Data

# %%
# upload the data and unzip it. You will see data/ with train/ and valid/. 
# !unzip supertux_classification_trainval.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/valid/01459.jpg
#   inflating: data/valid/07634.jpg
#   inflating: data/valid/03796.jpg
#   inflating: data/valid/01876.jpg
#   inflating: data/valid/04080.jpg
#   inflating: data/valid/06760.jpg
#   inflating: data/valid/01166.jpg
#   inflating: data/valid/00688.jpg
#   inflating: data/valid/05105.jpg
#   inflating: data/valid/04383.jpg
#   inflating: data/valid/04247.jpg
#   inflating: data/valid/06901.jpg
#   inflating: data/valid/04474.jpg
#   inflating: data/valid/06578.jpg
#   inflating: data/valid/08029.jpg
#   inflating: data/valid/04938.jpg
#   inflating: data/valid/03360.jpg
#   inflating: data/valid/05495.jpg
#   inflating: data/valid/02161.jpg
#   inflating: data/valid/02457.jpg
#   inflating: data/valid/03629.jpg
#   inflating: data/valid/03033.jpg
#   inflating: data/valid/00973.jpg
#   inflating: data/valid/05319.jpg
#   inflating: data/valid/07926.jpg
#   inflating: data/valid/03534.jpg
#   inflating: data/valid/03941.jpg
#   inflating: data/valid/03880.jpg
#   inflating: data/valid/02776.jpg
#   inflating: data/valid/05716.jpg
#   inflating: data/valid/05277.jpg
#   inflating: data/valid/06232.jpg
#   inflating: data/valid/03766.jpg
#   inflating: data/valid/04261.jpg
#   inflating: data/valid/03715.jpg
#   inflating: data/valid/04851.jpg
#   inflating: data/valid/03004.jpg
#   inflating: data/valid/04105.jpg
#   inflating: data/valid/03125.jpg
#   inflating: data/valid/08144.jpg
#   inflating: data/valid/03385.jpg
#   inflating: data/valid/05210.jpg
#   inflating: data/valid/06046.jpg
#   inflating: data/valid/06898.jpg
#   inflating: data/valid/03448.jpg
#   inflating: data/valid/05711.jpg
#   inflating: data/valid/03982.jpg
#   inflating: data/valid/00138.jpg
#   inflating: data/valid/00090.jpg
#   inflating: data/valid/02529.jpg
#   inflating: data/valid/06733.jpg
#   inflating: data/valid/04318.jpg
#   inflating: data/valid/08605.jpg
#   inflating: data/valid/03675.jpg
#   inflating: data/valid/02853.jpg
#   inflating: data/valid/02125.jpg
#   inflating: data/valid/04482.jpg
#   inflating: data/valid/08286.jpg
#   inflating: data/valid/05325.jpg
#   inflating: data/valid/05784.jpg
#   inflating: data/valid/07060.jpg
#   inflating: data/valid/06551.jpg
#   inflating: data/valid/02446.jpg
#   inflating: data/valid/00892.jpg
#   inflating: data/valid/01586.jpg
#   inflating: data/valid/05958.jpg
#   inflating: data/valid/04191.jpg
#   inflating: data/valid/00319.jpg
#   inflating: data/valid/07682.jpg
#   inflating: data/valid/02790.jpg
#   inflating: data/valid/01959.jpg
#   inflating: data/valid/00846.jpg
#   inflating: data/valid/01398.jpg
#   inflating: data/valid/07361.jpg
#   inflating: data/valid/04099.jpg
#   inflating: data/valid/07943.jpg
#   inflating: data/valid/07587.jpg
#   inflating: data/valid/00300.jpg
#   inflating: data/valid/04103.jpg
#   inflating: data/valid/05606.jpg
#   inflating: data/valid/05498.jpg
#   inflating: data/valid/02101.jpg
#   inflating: data/valid/01414.jpg
#   inflating: data/valid/01045.jpg
#   inflating: data/valid/07210.jpg
#   inflating: data/valid/01754.jpg
#   inflating: data/valid/06893.jpg
#   inflating: data/valid/03979.jpg
#   inflating: data/valid/00128.jpg
#   inflating: data/valid/02545.jpg
#   inflating: data/valid/06629.jpg
#   inflating: data/valid/04984.jpg
#   inflating: data/valid/02160.jpg
#   inflating: data/valid/02063.jpg
#   inflating: data/valid/08683.jpg
#   inflating: data/valid/08608.jpg
#   inflating: data/valid/07739.jpg
#   inflating: data/valid/05783.jpg
#   inflating: data/valid/06928.jpg
#   inflating: data/valid/06055.jpg
#   inflating: data/valid/01195.jpg
#   inflating: data/valid/02024.jpg
#   inflating: data/valid/06529.jpg
#   inflating: data/valid/02480.jpg
#   inflating: data/valid/05504.jpg
#   inflating: data/valid/05091.jpg
#   inflating: data/valid/01728.jpg
#   inflating: data/valid/04478.jpg
#   inflating: data/valid/04451.jpg
#   inflating: data/valid/05217.jpg
#   inflating: data/valid/00794.jpg
#   inflating: data/valid/04610.jpg
#   inflating: data/valid/04111.jpg
#   inflating: data/valid/04645.jpg
#   inflating: data/valid/01396.jpg
#   inflating: data/valid/06808.jpg
#   inflating: data/valid/07336.jpg
#   inflating: data/valid/07049.jpg
#   inflating: data/valid/07342.jpg
#   inflating: data/valid/03707.jpg
#   inflating: data/valid/07261.jpg
#   inflating: data/valid/02609.jpg
#   inflating: data/valid/08764.jpg
#   inflating: data/valid/03567.jpg
#   inflating: data/valid/01483.jpg
#   inflating: data/valid/00011.jpg
#   inflating: data/valid/07532.jpg
#   inflating: data/valid/01576.jpg
#   inflating: data/valid/00495.jpg
#   inflating: data/valid/07358.jpg
#   inflating: data/valid/00536.jpg
#   inflating: data/valid/05748.jpg
#   inflating: data/valid/02087.jpg
#   inflating: data/valid/03273.jpg
#   inflating: data/valid/07792.jpg
#   inflating: data/valid/03874.jpg
#   inflating: data/valid/01172.jpg
#   inflating: data/valid/00571.jpg
#   inflating: data/valid/04084.jpg
#   inflating: data/valid/02941.jpg
#   inflating: data/valid/00843.jpg
#   inflating: data/valid/01032.jpg
#   inflating: data/valid/01235.jpg
#   inflating: data/valid/08141.jpg
#   inflating: data/valid/07516.jpg
#   inflating: data/valid/01437.jpg
#   inflating: data/valid/05686.jpg
#   inflating: data/valid/03320.jpg
#   inflating: data/valid/05244.jpg
#   inflating: data/valid/05563.jpg
#   inflating: data/valid/02594.jpg
#   inflating: data/valid/04241.jpg
#   inflating: data/valid/04473.jpg
#   inflating: data/valid/04113.jpg
#   inflating: data/valid/04641.jpg
#   inflating: data/valid/02060.jpg
#   inflating: data/valid/02141.jpg
#   inflating: data/valid/02714.jpg
#   inflating: data/valid/03083.jpg
#   inflating: data/valid/07774.jpg
#   inflating: data/valid/04150.jpg
#   inflating: data/valid/04264.jpg
#   inflating: data/valid/00642.jpg
#   inflating: data/valid/01908.jpg
#   inflating: data/valid/02465.jpg
#   inflating: data/valid/08716.jpg
#   inflating: data/valid/03685.jpg
#   inflating: data/valid/00479.jpg
#   inflating: data/valid/01103.jpg
#   inflating: data/valid/03924.jpg
#   inflating: data/valid/00307.jpg
#   inflating: data/valid/08388.jpg
#   inflating: data/valid/07650.jpg
#   inflating: data/valid/02014.jpg
#   inflating: data/valid/05074.jpg
#   inflating: data/valid/01426.jpg
#   inflating: data/valid/03133.jpg
#   inflating: data/valid/02062.jpg
#   inflating: data/valid/00405.jpg
#   inflating: data/valid/05438.jpg
#   inflating: data/valid/02824.jpg
#   inflating: data/valid/08188.jpg
#   inflating: data/valid/00567.jpg
#   inflating: data/valid/03593.jpg
#   inflating: data/valid/08100.jpg
#   inflating: data/valid/04980.jpg
#   inflating: data/valid/07760.jpg
#   inflating: data/valid/02395.jpg
#   inflating: data/valid/02289.jpg
#   inflating: data/valid/00188.jpg
#   inflating: data/valid/00601.jpg
#   inflating: data/valid/02796.jpg
#   inflating: data/valid/07588.jpg
#   inflating: data/valid/04162.jpg
#   inflating: data/valid/04493.jpg
#   inflating: data/valid/06059.jpg
#   inflating: data/valid/05272.jpg
#   inflating: data/valid/00153.jpg
#   inflating: data/valid/07368.jpg
#   inflating: data/valid/06152.jpg
#   inflating: data/valid/08139.jpg
#   inflating: data/valid/06445.jpg
#   inflating: data/valid/07014.jpg
#   inflating: data/valid/00446.jpg
#   inflating: data/valid/02631.jpg
#   inflating: data/valid/01542.jpg
#   inflating: data/valid/05268.jpg
#   inflating: data/valid/02031.jpg
#   inflating: data/valid/07194.jpg
#   inflating: data/valid/01072.jpg
#   inflating: data/valid/03192.jpg
#   inflating: data/valid/06627.jpg
#   inflating: data/valid/07000.jpg
#   inflating: data/valid/01570.jpg
#   inflating: data/valid/01430.jpg
#   inflating: data/valid/06435.jpg
#   inflating: data/valid/00109.jpg
#   inflating: data/valid/06280.jpg
#   inflating: data/valid/06860.jpg
#   inflating: data/valid/00784.jpg
#   inflating: data/valid/07384.jpg
#   inflating: data/valid/08722.jpg
#   inflating: data/valid/02237.jpg
#   inflating: data/valid/06846.jpg
#   inflating: data/valid/01478.jpg
#   inflating: data/valid/04268.jpg
#   inflating: data/valid/05144.jpg
#   inflating: data/valid/08115.jpg
#   inflating: data/valid/05767.jpg
#   inflating: data/valid/07221.jpg
#   inflating: data/valid/05589.jpg
#   inflating: data/valid/03630.jpg
#   inflating: data/valid/03997.jpg
#   inflating: data/valid/08579.jpg
#   inflating: data/valid/07712.jpg
#   inflating: data/valid/03438.jpg
#   inflating: data/valid/03788.jpg
#   inflating: data/valid/01475.jpg
#   inflating: data/valid/06763.jpg
#   inflating: data/valid/07431.jpg
#   inflating: data/valid/05197.jpg
#   inflating: data/valid/05683.jpg
#   inflating: data/valid/03622.jpg
#   inflating: data/valid/05614.jpg
#   inflating: data/valid/04429.jpg
#   inflating: data/valid/00563.jpg
#   inflating: data/valid/07583.jpg
#   inflating: data/valid/06994.jpg
#   inflating: data/valid/07063.jpg
#   inflating: data/valid/08165.jpg
#   inflating: data/valid/07158.jpg
#   inflating: data/valid/06226.jpg
#   inflating: data/valid/07931.jpg
#   inflating: data/valid/05537.jpg
#   inflating: data/valid/07504.jpg
#   inflating: data/valid/00865.jpg
#   inflating: data/valid/01777.jpg
#   inflating: data/valid/03211.jpg
#   inflating: data/valid/05499.jpg
#   inflating: data/valid/02646.jpg
#   inflating: data/valid/04758.jpg
#   inflating: data/valid/07287.jpg
#   inflating: data/valid/07839.jpg
#   inflating: data/valid/06690.jpg
#   inflating: data/valid/08372.jpg
#   inflating: data/valid/01780.jpg
#   inflating: data/valid/01201.jpg
#   inflating: data/valid/01744.jpg
#   inflating: data/valid/01844.jpg
#   inflating: data/valid/00703.jpg
#   inflating: data/valid/02817.jpg
#   inflating: data/valid/00812.jpg
#   inflating: data/valid/00718.jpg
#   inflating: data/valid/06327.jpg
#   inflating: data/valid/08708.jpg
#   inflating: data/valid/07238.jpg
#   inflating: data/valid/03925.jpg
#   inflating: data/valid/02021.jpg
#   inflating: data/valid/01696.jpg
#   inflating: data/valid/02430.jpg
#   inflating: data/valid/05697.jpg
#   inflating: data/valid/06719.jpg
#   inflating: data/valid/06676.jpg
#   inflating: data/valid/08059.jpg
#   inflating: data/valid/00969.jpg
#   inflating: data/valid/03351.jpg
#   inflating: data/valid/01523.jpg
#   inflating: data/valid/06915.jpg
#   inflating: data/valid/07360.jpg
#   inflating: data/valid/00726.jpg
#   inflating: data/valid/06436.jpg
#   inflating: data/valid/01338.jpg
#   inflating: data/valid/08747.jpg
#   inflating: data/valid/01979.jpg
#   inflating: data/valid/07941.jpg
#   inflating: data/valid/03878.jpg
#   inflating: data/valid/04351.jpg
#   inflating: data/valid/03961.jpg
#   inflating: data/valid/02523.jpg
#   inflating: data/valid/05638.jpg
#   inflating: data/valid/03818.jpg
#   inflating: data/valid/00357.jpg
#   inflating: data/valid/08901.jpg
#   inflating: data/valid/00597.jpg
#   inflating: data/valid/03912.jpg
#   inflating: data/valid/00200.jpg
#   inflating: data/valid/01344.jpg
#   inflating: data/valid/08787.jpg
#   inflating: data/valid/07135.jpg
#   inflating: data/valid/02094.jpg
#   inflating: data/valid/07642.jpg
#   inflating: data/valid/04695.jpg
#   inflating: data/valid/04973.jpg
#   inflating: data/valid/05804.jpg
#   inflating: data/valid/07840.jpg
#   inflating: data/valid/03279.jpg
#   inflating: data/valid/05286.jpg
#   inflating: data/valid/06377.jpg
#   inflating: data/valid/00557.jpg
#   inflating: data/valid/04313.jpg
#   inflating: data/valid/04508.jpg
#   inflating: data/valid/08349.jpg
#   inflating: data/valid/03310.jpg
#   inflating: data/valid/07406.jpg
#   inflating: data/valid/06769.jpg
#   inflating: data/valid/05607.jpg
#   inflating: data/valid/02892.jpg
#   inflating: data/valid/01944.jpg
#   inflating: data/valid/08199.jpg
#   inflating: data/valid/02400.jpg
#   inflating: data/valid/04644.jpg
#   inflating: data/valid/04321.jpg
#   inflating: data/valid/04781.jpg
#   inflating: data/valid/07363.jpg
#   inflating: data/valid/01689.jpg
#   inflating: data/valid/04633.jpg
#   inflating: data/valid/00260.jpg
#   inflating: data/valid/06831.jpg
#   inflating: data/valid/05666.jpg
#   inflating: data/valid/00942.jpg
#   inflating: data/valid/07395.jpg
#   inflating: data/valid/06066.jpg
#   inflating: data/valid/05573.jpg
#   inflating: data/valid/02419.jpg
#   inflating: data/valid/02414.jpg
#   inflating: data/valid/07849.jpg
#   inflating: data/valid/01063.jpg
#   inflating: data/valid/03447.jpg
#   inflating: data/valid/05684.jpg
#   inflating: data/valid/08679.jpg
#   inflating: data/valid/01812.jpg
#   inflating: data/valid/01924.jpg
#   inflating: data/valid/08613.jpg
#   inflating: data/valid/06427.jpg
#   inflating: data/valid/08709.jpg
#   inflating: data/valid/04813.jpg
#   inflating: data/valid/05692.jpg
#   inflating: data/valid/07182.jpg
#   inflating: data/valid/04467.jpg
#   inflating: data/valid/04793.jpg
#   inflating: data/valid/00293.jpg
#   inflating: data/valid/01102.jpg
#   inflating: data/valid/00306.jpg
#   inflating: data/valid/06852.jpg
#   inflating: data/valid/02282.jpg
#   inflating: data/valid/08756.jpg
#   inflating: data/valid/08652.jpg
#   inflating: data/valid/03397.jpg
#   inflating: data/valid/03499.jpg
#   inflating: data/valid/06245.jpg
#   inflating: data/valid/02360.jpg
#   inflating: data/valid/04873.jpg
#   inflating: data/valid/05657.jpg
#   inflating: data/valid/05561.jpg
#   inflating: data/valid/02482.jpg
#   inflating: data/valid/04340.jpg
#   inflating: data/valid/03165.jpg
#   inflating: data/valid/00529.jpg
#   inflating: data/valid/06598.jpg
#   inflating: data/valid/04092.jpg
#   inflating: data/valid/02208.jpg
#   inflating: data/valid/08039.jpg
#   inflating: data/valid/00335.jpg
#   inflating: data/valid/04635.jpg
#   inflating: data/valid/00940.jpg
#   inflating: data/valid/04226.jpg
#   inflating: data/valid/03573.jpg
#   inflating: data/valid/08433.jpg
#   inflating: data/valid/01695.jpg
#   inflating: data/valid/01510.jpg
#   inflating: data/valid/03919.jpg
#   inflating: data/valid/07665.jpg
#   inflating: data/valid/08280.jpg
#   inflating: data/valid/03747.jpg
#   inflating: data/valid/04417.jpg
#   inflating: data/valid/02680.jpg
#   inflating: data/valid/08288.jpg
#   inflating: data/valid/04797.jpg
#   inflating: data/valid/00857.jpg
#   inflating: data/valid/08117.jpg
#   inflating: data/valid/00458.jpg
#   inflating: data/valid/03901.jpg
#   inflating: data/valid/08869.jpg
#   inflating: data/valid/02096.jpg
#   inflating: data/valid/02478.jpg
#   inflating: data/valid/08959.jpg
#   inflating: data/valid/04049.jpg
#   inflating: data/valid/03576.jpg
#   inflating: data/valid/00191.jpg
#   inflating: data/valid/00938.jpg
#   inflating: data/valid/00926.jpg
#   inflating: data/valid/06300.jpg
#   inflating: data/valid/08602.jpg
#   inflating: data/valid/08394.jpg
#   inflating: data/valid/01357.jpg
#   inflating: data/valid/04337.jpg
#   inflating: data/valid/01722.jpg
#   inflating: data/valid/00650.jpg
#   inflating: data/valid/05360.jpg
#   inflating: data/valid/02954.jpg
#   inflating: data/valid/02244.jpg
#   inflating: data/valid/00842.jpg
#   inflating: data/valid/00277.jpg
#   inflating: data/valid/05674.jpg
#   inflating: data/valid/01148.jpg
#   inflating: data/valid/06067.jpg
#   inflating: data/valid/04913.jpg
#   inflating: data/valid/02515.jpg
#   inflating: data/valid/05533.jpg
#   inflating: data/valid/02947.jpg
#   inflating: data/valid/00245.jpg
#   inflating: data/valid/05359.jpg
#   inflating: data/valid/08491.jpg
#   inflating: data/valid/01132.jpg
#   inflating: data/valid/06380.jpg
#   inflating: data/valid/00456.jpg
#   inflating: data/valid/03204.jpg
#   inflating: data/valid/02492.jpg
#   inflating: data/valid/05580.jpg
#   inflating: data/valid/05597.jpg
#   inflating: data/valid/07517.jpg
#   inflating: data/valid/06610.jpg
#   inflating: data/valid/04088.jpg
#   inflating: data/valid/07726.jpg
#   inflating: data/valid/00213.jpg
#   inflating: data/valid/06557.jpg
#   inflating: data/valid/07783.jpg
#   inflating: data/valid/03758.jpg
#   inflating: data/valid/06096.jpg
#   inflating: data/valid/01730.jpg
#   inflating: data/valid/07004.jpg
#   inflating: data/valid/06752.jpg
#   inflating: data/valid/07710.jpg
#   inflating: data/valid/02634.jpg
#   inflating: data/valid/06887.jpg
#   inflating: data/valid/04844.jpg
#   inflating: data/valid/08259.jpg
#   inflating: data/valid/02495.jpg
#   inflating: data/valid/03634.jpg
#   inflating: data/valid/05538.jpg
#   inflating: data/valid/02842.jpg
#   inflating: data/valid/01930.jpg
#   inflating: data/valid/06736.jpg
#   inflating: data/valid/04349.jpg
#   inflating: data/valid/03475.jpg
#   inflating: data/valid/00902.jpg
#   inflating: data/valid/02404.jpg
#   inflating: data/valid/03329.jpg
#   inflating: data/valid/04838.jpg
#   inflating: data/valid/01214.jpg
#   inflating: data/valid/08380.jpg
#   inflating: data/valid/04303.jpg
#   inflating: data/valid/01684.jpg
#   inflating: data/valid/03865.jpg
#   inflating: data/valid/01052.jpg
#   inflating: data/valid/07453.jpg
#   inflating: data/valid/05960.jpg
#   inflating: data/valid/01709.jpg
#   inflating: data/valid/05840.jpg
#   inflating: data/valid/00990.jpg
#   inflating: data/valid/04091.jpg
#   inflating: data/valid/02917.jpg
#   inflating: data/valid/06200.jpg
#   inflating: data/valid/05456.jpg
#   inflating: data/valid/00550.jpg
#   inflating: data/valid/05419.jpg
#   inflating: data/valid/02964.jpg
#   inflating: data/valid/07704.jpg
#   inflating: data/valid/01649.jpg
#   inflating: data/valid/06821.jpg
#   inflating: data/valid/06483.jpg
#   inflating: data/valid/06724.jpg
#   inflating: data/valid/06522.jpg
#   inflating: data/valid/01213.jpg
#   inflating: data/valid/01010.jpg
#   inflating: data/valid/07457.jpg
#   inflating: data/valid/01013.jpg
#   inflating: data/valid/00378.jpg
#   inflating: data/valid/07552.jpg
#   inflating: data/valid/05320.jpg
#   inflating: data/valid/04907.jpg
#   inflating: data/valid/08444.jpg
#   inflating: data/valid/04023.jpg
#   inflating: data/valid/04550.jpg
#   inflating: data/valid/00332.jpg
#   inflating: data/valid/01981.jpg
#   inflating: data/valid/03920.jpg
#   inflating: data/valid/02092.jpg
#   inflating: data/valid/06927.jpg
#   inflating: data/valid/02739.jpg
#   inflating: data/valid/08686.jpg
#   inflating: data/valid/02936.jpg
#   inflating: data/valid/06757.jpg
#   inflating: data/valid/03581.jpg
#   inflating: data/valid/02421.jpg
#   inflating: data/valid/00750.jpg
#   inflating: data/valid/03127.jpg
#   inflating: data/valid/04192.jpg
#   inflating: data/valid/04426.jpg
#   inflating: data/valid/06364.jpg
#   inflating: data/valid/06041.jpg
#   inflating: data/valid/04600.jpg
#   inflating: data/valid/02136.jpg
#   inflating: data/valid/01433.jpg
#   inflating: data/valid/07566.jpg
#   inflating: data/valid/02098.jpg
#   inflating: data/valid/03270.jpg
#   inflating: data/valid/06657.jpg
#   inflating: data/valid/02844.jpg
#   inflating: data/valid/02085.jpg
#   inflating: data/valid/00472.jpg
#   inflating: data/valid/01086.jpg
#   inflating: data/valid/04311.jpg
#   inflating: data/valid/00615.jpg
#   inflating: data/valid/00155.jpg
#   inflating: data/valid/02347.jpg
#   inflating: data/valid/04556.jpg
#   inflating: data/valid/00223.jpg
#   inflating: data/valid/03737.jpg
#   inflating: data/valid/08849.jpg
#   inflating: data/valid/05713.jpg
#   inflating: data/valid/05365.jpg
#   inflating: data/valid/05531.jpg
#   inflating: data/valid/01737.jpg
#   inflating: data/valid/00745.jpg
#   inflating: data/valid/01707.jpg
#   inflating: data/valid/01803.jpg
#   inflating: data/valid/00442.jpg
#   inflating: data/valid/00950.jpg
#   inflating: data/valid/08316.jpg
#   inflating: data/valid/01352.jpg
#   inflating: data/valid/02827.jpg
#   inflating: data/valid/02975.jpg
#   inflating: data/valid/03681.jpg
#   inflating: data/valid/03515.jpg
#   inflating: data/valid/02988.jpg
#   inflating: data/valid/05930.jpg
#   inflating: data/valid/05489.jpg
#   inflating: data/valid/02068.jpg
#   inflating: data/valid/07041.jpg
#   inflating: data/valid/08835.jpg
#   inflating: data/valid/07572.jpg
#   inflating: data/valid/02881.jpg
#   inflating: data/valid/07494.jpg
#   inflating: data/valid/04260.jpg
#   inflating: data/valid/08062.jpg
#   inflating: data/valid/04229.jpg
#   inflating: data/valid/03885.jpg
#   inflating: data/valid/04741.jpg
#   inflating: data/valid/03759.jpg
#   inflating: data/valid/00652.jpg
#   inflating: data/valid/05007.jpg
#   inflating: data/valid/00392.jpg
#   inflating: data/valid/07166.jpg
#   inflating: data/valid/05470.jpg
#   inflating: data/valid/01229.jpg
#   inflating: data/valid/05849.jpg
#   inflating: data/valid/03341.jpg
#   inflating: data/valid/00863.jpg
#   inflating: data/valid/00856.jpg
#   inflating: data/valid/05235.jpg
#   inflating: data/valid/04916.jpg
#   inflating: data/valid/07393.jpg
#   inflating: data/valid/03509.jpg
#   inflating: data/valid/06406.jpg
#   inflating: data/valid/00762.jpg
#   inflating: data/valid/06231.jpg
#   inflating: data/valid/04818.jpg
#   inflating: data/valid/01889.jpg
#   inflating: data/valid/05550.jpg
#   inflating: data/valid/06595.jpg
#   inflating: data/valid/08767.jpg
#   inflating: data/valid/01829.jpg
#   inflating: data/valid/00048.jpg
#   inflating: data/valid/01362.jpg
#   inflating: data/valid/01781.jpg
#   inflating: data/valid/07864.jpg
#   inflating: data/valid/00438.jpg
#   inflating: data/valid/06728.jpg
#   inflating: data/valid/01783.jpg
#   inflating: data/valid/00849.jpg
#   inflating: data/valid/01034.jpg
#   inflating: data/valid/06816.jpg
#   inflating: data/valid/06099.jpg
#   inflating: data/valid/01322.jpg
#   inflating: data/valid/02344.jpg
#   inflating: data/valid/03995.jpg
#   inflating: data/valid/00787.jpg
#   inflating: data/valid/08130.jpg
#   inflating: data/valid/02241.jpg
#   inflating: data/valid/01850.jpg
#   inflating: data/valid/00118.jpg
#   inflating: data/valid/02346.jpg
#   inflating: data/valid/04376.jpg
#   inflating: data/valid/07813.jpg
#   inflating: data/valid/04882.jpg
#   inflating: data/valid/07589.jpg
#   inflating: data/valid/04558.jpg
#   inflating: data/valid/01084.jpg
#   inflating: data/valid/04660.jpg
#   inflating: data/valid/00705.jpg
#   inflating: data/valid/05867.jpg
#   inflating: data/valid/04144.jpg
#   inflating: data/valid/03595.jpg
#   inflating: data/valid/04941.jpg
#   inflating: data/valid/05496.jpg
#   inflating: data/valid/00805.jpg
#   inflating: data/valid/00235.jpg
#   inflating: data/valid/04512.jpg
#   inflating: data/valid/03488.jpg
#   inflating: data/valid/00022.jpg
#   inflating: data/valid/08411.jpg
#   inflating: data/valid/03071.jpg
#   inflating: data/valid/07159.jpg
#   inflating: data/valid/05931.jpg
#   inflating: data/valid/05298.jpg
#   inflating: data/valid/00474.jpg
#   inflating: data/valid/06622.jpg
#   inflating: data/valid/03856.jpg
#   inflating: data/valid/06949.jpg
#   inflating: data/valid/00497.jpg
#   inflating: data/valid/05821.jpg
#   inflating: data/valid/06008.jpg
#   inflating: data/valid/08498.jpg
#   inflating: data/valid/00949.jpg
#   inflating: data/valid/02533.jpg
#   inflating: data/valid/01940.jpg
#   inflating: data/valid/01879.jpg
#   inflating: data/valid/06147.jpg
#   inflating: data/valid/01718.jpg
#   inflating: data/valid/04981.jpg
#   inflating: data/valid/05893.jpg
#   inflating: data/valid/07218.jpg
#   inflating: data/valid/08820.jpg
#   inflating: data/valid/06973.jpg
#   inflating: data/valid/00356.jpg
#   inflating: data/valid/04932.jpg
#   inflating: data/valid/01224.jpg
#   inflating: data/valid/02712.jpg
#   inflating: data/valid/02841.jpg
#   inflating: data/valid/04883.jpg
#   inflating: data/valid/04411.jpg
#   inflating: data/valid/04751.jpg
#   inflating: data/valid/01406.jpg
#   inflating: data/valid/00215.jpg
#   inflating: data/valid/02702.jpg
#   inflating: data/valid/07201.jpg
#   inflating: data/valid/07630.jpg
#   inflating: data/valid/08471.jpg
#   inflating: data/valid/04037.jpg
#   inflating: data/valid/04072.jpg
#   inflating: data/valid/08618.jpg
#   inflating: data/valid/08121.jpg
#   inflating: data/valid/08045.jpg
#   inflating: data/valid/08445.jpg
#   inflating: data/valid/04749.jpg
#   inflating: data/valid/07035.jpg
#   inflating: data/valid/02968.jpg
#   inflating: data/valid/06866.jpg
#   inflating: data/valid/06420.jpg
#   inflating: data/valid/02875.jpg
#   inflating: data/valid/05202.jpg
#   inflating: data/valid/07692.jpg
#   inflating: data/valid/06984.jpg
#   inflating: data/valid/07246.jpg
#   inflating: data/valid/02556.jpg
#   inflating: data/valid/00331.jpg
#   inflating: data/valid/05808.jpg
#   inflating: data/valid/01585.jpg
#   inflating: data/valid/03563.jpg
#   inflating: data/valid/05290.jpg
#   inflating: data/valid/05873.jpg
#   inflating: data/valid/00808.jpg
#   inflating: data/valid/02705.jpg
#   inflating: data/valid/03735.jpg
#   inflating: data/valid/05469.jpg
#   inflating: data/valid/06472.jpg
#   inflating: data/valid/01205.jpg
#   inflating: data/valid/04039.jpg
#   inflating: data/valid/07746.jpg
#   inflating: data/valid/08048.jpg
#   inflating: data/valid/00767.jpg
#   inflating: data/valid/02335.jpg
#   inflating: data/valid/02781.jpg
#   inflating: data/valid/04874.jpg
#   inflating: data/valid/06857.jpg
#   inflating: data/valid/00727.jpg
#   inflating: data/valid/04199.jpg
#   inflating: data/valid/02152.jpg
#   inflating: data/valid/02462.jpg
#   inflating: data/valid/00323.jpg
#   inflating: data/valid/05539.jpg
#   inflating: data/valid/02447.jpg
#   inflating: data/valid/02454.jpg
#   inflating: data/valid/01706.jpg
#   inflating: data/valid/02823.jpg
#   inflating: data/valid/07396.jpg
#   inflating: data/valid/08662.jpg
#   inflating: data/valid/05000.jpg
#   inflating: data/valid/01186.jpg
#   inflating: data/valid/01048.jpg
#   inflating: data/valid/02488.jpg
#   inflating: data/valid/07269.jpg
#   inflating: data/valid/02279.jpg
#   inflating: data/valid/03658.jpg
#   inflating: data/valid/01454.jpg
#   inflating: data/valid/02582.jpg
#   inflating: data/valid/03640.jpg
#   inflating: data/valid/00776.jpg
#   inflating: data/valid/08245.jpg
#   inflating: data/valid/04560.jpg
#   inflating: data/valid/06221.jpg
#   inflating: data/valid/07326.jpg
#   inflating: data/valid/04432.jpg
#   inflating: data/valid/06694.jpg
#   inflating: data/valid/00072.jpg
#   inflating: data/valid/05810.jpg
#   inflating: data/valid/04612.jpg
#   inflating: data/valid/02166.jpg
#   inflating: data/valid/06123.jpg
#   inflating: data/valid/05663.jpg
#   inflating: data/valid/03516.jpg
#   inflating: data/valid/01546.jpg
#   inflating: data/valid/01420.jpg
#   inflating: data/valid/05452.jpg
#   inflating: data/valid/05672.jpg
#   inflating: data/valid/08052.jpg
#   inflating: data/valid/08163.jpg
#   inflating: data/valid/05130.jpg
#   inflating: data/valid/08152.jpg
#   inflating: data/valid/08361.jpg
#   inflating: data/valid/06891.jpg
#   inflating: data/valid/02444.jpg
#   inflating: data/valid/05087.jpg
#   inflating: data/valid/05581.jpg
#   inflating: data/valid/00852.jpg
#   inflating: data/valid/05005.jpg
#   inflating: data/valid/00238.jpg
#   inflating: data/valid/01455.jpg
#   inflating: data/valid/03433.jpg
#   inflating: data/valid/07123.jpg
#   inflating: data/valid/06053.jpg
#   inflating: data/valid/01138.jpg
#   inflating: data/valid/04308.jpg
#   inflating: data/valid/08421.jpg
#   inflating: data/valid/02343.jpg
#   inflating: data/valid/01361.jpg
#   inflating: data/valid/00980.jpg
#   inflating: data/valid/07008.jpg
#   inflating: data/valid/02666.jpg
#   inflating: data/valid/00276.jpg
#   inflating: data/valid/02050.jpg
#   inflating: data/valid/07948.jpg
#   inflating: data/valid/06141.jpg
#   inflating: data/valid/08636.jpg
#   inflating: data/valid/04299.jpg
#   inflating: data/valid/07902.jpg
#   inflating: data/valid/06528.jpg
#   inflating: data/valid/06621.jpg
#   inflating: data/valid/01104.jpg
#   inflating: data/valid/07258.jpg
#   inflating: data/valid/07236.jpg
#   inflating: data/valid/08953.jpg
#   inflating: data/valid/01159.jpg
#   inflating: data/valid/01854.jpg
#   inflating: data/valid/04075.jpg
#   inflating: data/valid/05965.jpg
#   inflating: data/valid/06376.jpg
#   inflating: data/valid/06588.jpg
#   inflating: data/valid/02423.jpg
#   inflating: data/valid/03959.jpg
#   inflating: data/valid/00693.jpg
#   inflating: data/valid/06782.jpg
#   inflating: data/valid/05203.jpg
#   inflating: data/valid/07831.jpg
#   inflating: data/valid/07268.jpg
#   inflating: data/valid/07448.jpg
#   inflating: data/valid/02619.jpg
#   inflating: data/valid/04390.jpg
#   inflating: data/valid/04885.jpg
#   inflating: data/valid/03210.jpg
#   inflating: data/valid/07852.jpg
#   inflating: data/valid/05454.jpg
#   inflating: data/valid/05088.jpg
#   inflating: data/valid/06311.jpg
#   inflating: data/valid/00039.jpg
#   inflating: data/valid/04879.jpg
#   inflating: data/valid/00992.jpg
#   inflating: data/valid/07629.jpg
#   inflating: data/valid/03911.jpg
#   inflating: data/valid/02008.jpg
#   inflating: data/valid/00551.jpg
#   inflating: data/valid/02131.jpg
#   inflating: data/valid/02986.jpg
#   inflating: data/valid/03043.jpg
#   inflating: data/valid/00643.jpg
#   inflating: data/valid/01602.jpg
#   inflating: data/valid/01821.jpg
#   inflating: data/valid/05407.jpg
#   inflating: data/valid/04920.jpg
#   inflating: data/valid/06456.jpg
#   inflating: data/valid/06778.jpg
#   inflating: data/valid/08044.jpg
#   inflating: data/valid/08755.jpg
#   inflating: data/valid/03291.jpg
#   inflating: data/valid/07190.jpg
#   inflating: data/valid/00941.jpg
#   inflating: data/valid/05429.jpg
#   inflating: data/valid/04497.jpg
#   inflating: data/valid/06247.jpg
#   inflating: data/valid/02899.jpg
#   inflating: data/valid/05847.jpg
#   inflating: data/valid/04669.jpg
#   inflating: data/valid/06492.jpg
#   inflating: data/valid/01926.jpg
#   inflating: data/valid/02431.jpg
#   inflating: data/valid/07385.jpg
#   inflating: data/valid/05616.jpg
#   inflating: data/valid/03219.jpg
#   inflating: data/valid/00269.jpg
#   inflating: data/valid/00922.jpg
#   inflating: data/valid/05340.jpg
#   inflating: data/valid/00370.jpg
#   inflating: data/valid/07923.jpg
#   inflating: data/valid/08556.jpg
#   inflating: data/valid/01146.jpg
#   inflating: data/valid/07380.jpg
#   inflating: data/valid/08627.jpg
#   inflating: data/valid/02598.jpg
#   inflating: data/valid/01025.jpg
#   inflating: data/valid/01278.jpg
#   inflating: data/valid/00197.jpg
#   inflating: data/valid/01733.jpg
#   inflating: data/valid/01256.jpg
#   inflating: data/valid/02011.jpg
#   inflating: data/valid/05844.jpg
#   inflating: data/valid/01726.jpg
#   inflating: data/valid/00023.jpg
#   inflating: data/valid/05025.jpg
#   inflating: data/valid/08957.jpg
#   inflating: data/valid/05459.jpg
#   inflating: data/valid/00546.jpg
#   inflating: data/valid/00624.jpg
#   inflating: data/valid/07787.jpg
#   inflating: data/valid/04343.jpg
#   inflating: data/valid/07313.jpg
#   inflating: data/valid/08238.jpg
#   inflating: data/valid/07693.jpg
#   inflating: data/valid/06642.jpg
#   inflating: data/valid/05405.jpg
#   inflating: data/valid/03181.jpg
#   inflating: data/valid/00384.jpg
#   inflating: data/valid/06751.jpg
#   inflating: data/valid/06720.jpg
#   inflating: data/valid/07082.jpg
#   inflating: data/valid/01738.jpg
#   inflating: data/valid/03294.jpg
#   inflating: data/valid/01855.jpg
#   inflating: data/valid/06682.jpg
#   inflating: data/valid/08078.jpg
#   inflating: data/valid/00923.jpg
#   inflating: data/valid/08580.jpg
#   inflating: data/valid/05057.jpg
#   inflating: data/valid/03106.jpg
#   inflating: data/valid/00736.jpg
#   inflating: data/valid/06003.jpg
#   inflating: data/valid/06184.jpg
#   inflating: data/valid/04082.jpg
#   inflating: data/valid/00872.jpg
#   inflating: data/valid/04479.jpg
#   inflating: data/valid/08609.jpg
#   inflating: data/valid/02229.jpg
#   inflating: data/valid/05901.jpg
#   inflating: data/valid/06840.jpg
#   inflating: data/valid/01909.jpg
#   inflating: data/valid/07327.jpg
#   inflating: data/valid/05342.jpg
#   inflating: data/valid/00069.jpg
#   inflating: data/valid/05163.jpg
#   inflating: data/valid/08797.jpg
#   inflating: data/valid/05772.jpg
#   inflating: data/valid/06394.jpg
#   inflating: data/valid/02265.jpg
#   inflating: data/valid/02918.jpg
#   inflating: data/valid/02951.jpg
#   inflating: data/valid/05283.jpg
#   inflating: data/valid/06602.jpg
#   inflating: data/valid/00545.jpg
#   inflating: data/valid/01561.jpg
#   inflating: data/valid/07882.jpg
#   inflating: data/valid/00639.jpg
#   inflating: data/valid/02595.jpg
#   inflating: data/valid/07622.jpg
#   inflating: data/valid/01582.jpg
#   inflating: data/valid/02026.jpg
#   inflating: data/valid/06867.jpg
#   inflating: data/valid/00321.jpg
#   inflating: data/valid/02503.jpg
#   inflating: data/valid/01215.jpg
#   inflating: data/valid/06805.jpg
#   inflating: data/valid/06092.jpg
#   inflating: data/valid/08374.jpg
#   inflating: data/valid/08323.jpg
#   inflating: data/valid/05743.jpg
#   inflating: data/valid/02889.jpg
#   inflating: data/valid/03641.jpg
#   inflating: data/valid/07944.jpg
#   inflating: data/valid/05079.jpg
#   inflating: data/valid/05629.jpg
#   inflating: data/valid/04204.jpg
#   inflating: data/valid/06222.jpg
#   inflating: data/valid/08860.jpg
#   inflating: data/valid/02313.jpg
#   inflating: data/valid/07050.jpg
#   inflating: data/valid/04622.jpg
#   inflating: data/valid/01502.jpg
#   inflating: data/valid/02509.jpg
#   inflating: data/valid/08450.jpg
#   inflating: data/valid/01350.jpg
#   inflating: data/valid/05833.jpg
#   inflating: data/valid/01894.jpg
#   inflating: data/valid/01504.jpg
#   inflating: data/valid/00486.jpg
#   inflating: data/valid/08311.jpg
#   inflating: data/valid/05065.jpg
#   inflating: data/valid/00180.jpg
#   inflating: data/valid/02650.jpg
#   inflating: data/valid/02872.jpg
#   inflating: data/valid/07782.jpg
#   inflating: data/valid/08389.jpg
#   inflating: data/valid/01274.jpg
#   inflating: data/valid/03104.jpg
#   inflating: data/valid/05603.jpg
#   inflating: data/valid/02662.jpg
#   inflating: data/valid/00133.jpg
#   inflating: data/valid/01925.jpg
#   inflating: data/valid/03384.jpg
#   inflating: data/valid/06920.jpg
#   inflating: data/valid/06260.jpg
#   inflating: data/valid/06004.jpg
#   inflating: data/valid/04404.jpg
#   inflating: data/valid/06289.jpg
#   inflating: data/valid/05238.jpg
#   inflating: data/valid/05471.jpg
#   inflating: data/valid/06028.jpg
#   inflating: data/valid/02960.jpg
#   inflating: data/valid/03789.jpg
#   inflating: data/valid/02485.jpg
#   inflating: data/valid/08382.jpg
#   inflating: data/valid/05446.jpg
#   inflating: data/valid/07609.jpg
#   inflating: data/valid/01467.jpg
#   inflating: data/valid/04038.jpg
#   inflating: data/valid/05066.jpg
#   inflating: data/valid/01938.jpg
#   inflating: data/valid/07304.jpg
#   inflating: data/valid/07191.jpg
#   inflating: data/valid/07919.jpg
#   inflating: data/valid/01651.jpg
#   inflating: data/valid/08700.jpg
#   inflating: data/valid/06120.jpg
#   inflating: data/valid/08412.jpg
#   inflating: data/valid/04997.jpg
#   inflating: data/valid/02110.jpg
#   inflating: data/valid/02570.jpg
#   inflating: data/valid/07324.jpg
#   inflating: data/valid/04789.jpg
#   inflating: data/valid/04726.jpg
#   inflating: data/valid/07548.jpg
#   inflating: data/valid/08814.jpg
#   inflating: data/valid/04705.jpg
#   inflating: data/valid/02056.jpg
#   inflating: data/valid/06270.jpg
#   inflating: data/valid/05414.jpg
#   inflating: data/valid/08517.jpg
#   inflating: data/valid/06361.jpg
#   inflating: data/valid/00187.jpg
#   inflating: data/valid/00955.jpg
#   inflating: data/valid/05164.jpg
#   inflating: data/valid/08346.jpg
#   inflating: data/valid/02321.jpg
#   inflating: data/valid/06770.jpg
#   inflating: data/valid/01212.jpg
#   inflating: data/valid/08942.jpg
#   inflating: data/valid/05800.jpg
#   inflating: data/valid/00763.jpg
#   inflating: data/valid/03577.jpg
#   inflating: data/valid/03484.jpg
#   inflating: data/valid/01917.jpg
#   inflating: data/valid/06842.jpg
#   inflating: data/valid/07772.jpg
#   inflating: data/valid/00292.jpg
#   inflating: data/valid/01899.jpg
#   inflating: data/valid/03833.jpg
#   inflating: data/valid/08995.jpg
#   inflating: data/valid/00045.jpg
#   inflating: data/valid/07001.jpg
#   inflating: data/valid/01635.jpg
#   inflating: data/valid/00364.jpg
#   inflating: data/valid/01500.jpg
#   inflating: data/valid/08896.jpg
#   inflating: data/valid/08040.jpg
#   inflating: data/valid/04443.jpg
#   inflating: data/valid/05313.jpg
#   inflating: data/valid/06696.jpg
#   inflating: data/valid/08309.jpg
#   inflating: data/valid/03142.jpg
#   inflating: data/valid/05540.jpg
#   inflating: data/valid/06517.jpg
#   inflating: data/valid/08237.jpg
#   inflating: data/valid/02901.jpg
#   inflating: data/valid/01380.jpg
#   inflating: data/valid/08691.jpg
#   inflating: data/valid/07804.jpg
#   inflating: data/valid/03609.jpg
#   inflating: data/valid/02586.jpg
#   inflating: data/valid/05628.jpg
#   inflating: data/valid/07834.jpg
#   inflating: data/valid/04483.jpg
#   inflating: data/valid/08096.jpg
#   inflating: data/valid/01331.jpg
#   inflating: data/valid/04772.jpg
#   inflating: data/valid/02516.jpg
#   inflating: data/valid/05822.jpg
#   inflating: data/valid/02965.jpg
#   inflating: data/valid/07771.jpg
#   inflating: data/valid/06899.jpg
#   inflating: data/valid/04703.jpg
#   inflating: data/valid/02304.jpg
#   inflating: data/valid/01301.jpg
#   inflating: data/valid/08920.jpg
#   inflating: data/valid/02469.jpg
#   inflating: data/valid/03050.jpg
#   inflating: data/valid/03111.jpg
#   inflating: data/valid/04623.jpg
#   inflating: data/valid/06366.jpg
#   inflating: data/valid/05871.jpg
#   inflating: data/valid/02778.jpg
#   inflating: data/valid/03906.jpg
#   inflating: data/valid/08977.jpg
#   inflating: data/valid/08810.jpg
#   inflating: data/valid/05785.jpg
#   inflating: data/valid/01427.jpg
#   inflating: data/valid/01241.jpg
#   inflating: data/valid/04160.jpg
#   inflating: data/valid/04368.jpg
#   inflating: data/valid/05855.jpg
#   inflating: data/valid/02042.jpg
#   inflating: data/valid/03107.jpg
#   inflating: data/valid/03852.jpg
#   inflating: data/valid/06005.jpg
#   inflating: data/valid/02035.jpg
#   inflating: data/valid/02929.jpg
#   inflating: data/valid/02387.jpg
#   inflating: data/valid/07040.jpg
#   inflating: data/valid/00830.jpg
#   inflating: data/valid/03967.jpg
#   inflating: data/valid/00689.jpg
#   inflating: data/valid/02153.jpg
#   inflating: data/valid/07372.jpg
#   inflating: data/valid/06722.jpg
#   inflating: data/valid/01903.jpg
#   inflating: data/valid/01051.jpg
#   inflating: data/valid/03705.jpg
#   inflating: data/valid/00101.jpg
#   inflating: data/valid/06228.jpg
#   inflating: data/valid/03935.jpg
#   inflating: data/valid/01276.jpg
#   inflating: data/valid/03969.jpg
#   inflating: data/valid/04197.jpg
#   inflating: data/valid/04030.jpg
#   inflating: data/valid/07775.jpg
#   inflating: data/valid/07917.jpg
#   inflating: data/valid/05664.jpg
#   inflating: data/valid/05139.jpg
#   inflating: data/valid/01326.jpg
#   inflating: data/valid/07377.jpg
#   inflating: data/valid/08948.jpg
#   inflating: data/valid/05600.jpg
#   inflating: data/valid/06091.jpg
#   inflating: data/valid/07335.jpg
#   inflating: data/valid/06171.jpg
#   inflating: data/valid/00291.jpg
#   inflating: data/valid/07499.jpg
#   inflating: data/valid/02938.jpg
#   inflating: data/valid/02350.jpg
#   inflating: data/valid/06839.jpg
#   inflating: data/valid/03194.jpg
#   inflating: data/valid/06873.jpg
#   inflating: data/valid/02361.jpg
#   inflating: data/valid/06323.jpg
#   inflating: data/valid/01018.jpg
#   inflating: data/valid/02487.jpg
#   inflating: data/valid/08384.jpg
#   inflating: data/valid/02891.jpg
#   inflating: data/valid/03571.jpg
#   inflating: data/valid/07300.jpg
#   inflating: data/valid/08183.jpg
#   inflating: data/valid/03066.jpg
#   inflating: data/valid/05006.jpg
#   inflating: data/valid/03156.jpg
#   inflating: data/valid/01540.jpg
#   inflating: data/valid/01321.jpg
#   inflating: data/valid/04540.jpg
#   inflating: data/valid/02753.jpg
#   inflating: data/valid/00132.jpg
#   inflating: data/valid/08051.jpg
#   inflating: data/valid/05321.jpg
#   inflating: data/valid/07670.jpg
#   inflating: data/valid/04567.jpg
#   inflating: data/valid/06631.jpg
#   inflating: data/valid/03287.jpg
#   inflating: data/valid/04950.jpg
#   inflating: data/valid/00820.jpg
#   inflating: data/valid/04292.jpg
#   inflating: data/valid/03063.jpg
#   inflating: data/valid/03101.jpg
#   inflating: data/valid/05305.jpg
#   inflating: data/valid/00627.jpg
#   inflating: data/valid/01108.jpg
#   inflating: data/valid/02205.jpg
#   inflating: data/valid/00982.jpg
#   inflating: data/valid/07074.jpg
#   inflating: data/valid/03293.jpg
#   inflating: data/valid/03574.jpg
#   inflating: data/valid/08907.jpg
#   inflating: data/valid/06236.jpg
#   inflating: data/valid/02882.jpg
#   inflating: data/valid/05278.jpg
#   inflating: data/valid/07078.jpg
#   inflating: data/valid/05369.jpg
#   inflating: data/valid/07578.jpg
#   inflating: data/valid/06526.jpg
#   inflating: data/valid/06439.jpg
#   inflating: data/valid/00113.jpg
#   inflating: data/valid/02542.jpg
#   inflating: data/valid/07983.jpg
#   inflating: data/valid/03502.jpg
#   inflating: data/valid/07276.jpg
#   inflating: data/valid/04431.jpg
#   inflating: data/valid/03720.jpg
#   inflating: data/valid/04227.jpg
#   inflating: data/valid/01869.jpg
#   inflating: data/valid/06015.jpg
#   inflating: data/valid/01129.jpg
#   inflating: data/valid/02565.jpg
#   inflating: data/valid/06142.jpg
#   inflating: data/valid/00423.jpg
#   inflating: data/valid/05449.jpg
#   inflating: data/valid/06524.jpg
#   inflating: data/valid/06078.jpg
#   inflating: data/valid/05736.jpg
#   inflating: data/valid/00375.jpg
#   inflating: data/valid/05436.jpg
#   inflating: data/valid/01901.jpg
#   inflating: data/valid/02744.jpg
#   inflating: data/valid/07214.jpg
#   inflating: data/valid/07064.jpg
#   inflating: data/valid/03586.jpg
#   inflating: data/valid/00927.jpg
#   inflating: data/valid/08211.jpg
#   inflating: data/valid/07615.jpg
#   inflating: data/valid/06646.jpg
#   inflating: data/valid/00193.jpg
#   inflating: data/valid/06153.jpg
#   inflating: data/valid/07953.jpg
#   inflating: data/valid/08751.jpg
#   inflating: data/valid/07611.jpg
#   inflating: data/valid/02611.jpg
#   inflating: data/valid/04146.jpg
#   inflating: data/valid/01951.jpg
#   inflating: data/valid/01663.jpg
#   inflating: data/valid/08099.jpg
#   inflating: data/valid/05029.jpg
#   inflating: data/valid/00960.jpg
#   inflating: data/valid/02722.jpg
#   inflating: data/valid/02837.jpg
#   inflating: data/valid/06263.jpg
#   inflating: data/valid/08159.jpg
#   inflating: data/valid/00991.jpg
#   inflating: data/valid/07286.jpg
#   inflating: data/valid/01541.jpg
#   inflating: data/valid/04193.jpg
#   inflating: data/valid/06820.jpg
#   inflating: data/valid/07779.jpg
#   inflating: data/valid/00054.jpg
#   inflating: data/valid/08890.jpg
#   inflating: data/valid/04126.jpg
#   inflating: data/valid/05049.jpg
#   inflating: data/valid/06605.jpg
#   inflating: data/valid/03864.jpg
#   inflating: data/valid/00984.jpg
#   inflating: data/valid/01798.jpg
#   inflating: data/valid/00611.jpg
#   inflating: data/valid/04583.jpg
#   inflating: data/valid/00517.jpg
#   inflating: data/valid/04405.jpg
#   inflating: data/valid/07244.jpg
#   inflating: data/valid/03729.jpg
#   inflating: data/valid/04445.jpg
#   inflating: data/valid/08892.jpg
#   inflating: data/valid/05928.jpg
#   inflating: data/valid/08592.jpg
#   inflating: data/valid/00815.jpg
#   inflating: data/valid/05500.jpg
#   inflating: data/valid/06683.jpg
#   inflating: data/valid/06473.jpg
#   inflating: data/valid/04799.jpg
#   inflating: data/valid/05757.jpg
#   inflating: data/valid/08004.jpg
#   inflating: data/valid/02604.jpg
#   inflating: data/valid/00527.jpg
#   inflating: data/valid/04524.jpg
#   inflating: data/valid/00541.jpg
#   inflating: data/valid/02519.jpg
#   inflating: data/valid/07216.jpg
#   inflating: data/valid/02999.jpg
#   inflating: data/valid/08698.jpg
#   inflating: data/valid/07275.jpg
#   inflating: data/valid/05848.jpg
#   inflating: data/valid/07764.jpg
#   inflating: data/valid/07071.jpg
#   inflating: data/valid/03984.jpg
#   inflating: data/valid/08870.jpg
#   inflating: data/valid/05937.jpg
#   inflating: data/valid/00005.jpg
#   inflating: data/valid/06835.jpg
#   inflating: data/valid/07487.jpg
#   inflating: data/valid/07424.jpg
#   inflating: data/valid/01001.jpg
#   inflating: data/valid/05983.jpg
#   inflating: data/valid/00288.jpg
#   inflating: data/valid/05782.jpg
#   inflating: data/valid/01912.jpg
#   inflating: data/valid/05947.jpg
#   inflating: data/valid/03132.jpg
#   inflating: data/valid/05915.jpg
#   inflating: data/valid/06056.jpg
#   inflating: data/valid/00379.jpg
#   inflating: data/valid/08682.jpg
#   inflating: data/valid/05248.jpg
# ...
#   inflating: data/valid/00720.jpg
#   inflating: data/valid/05067.jpg
#   inflating: data/valid/08882.jpg
#   inflating: data/valid/04034.jpg
#   inflating: data/valid/06177.jpg
#   inflating: data/valid/05167.jpg
#   inflating: data/valid/07163.jpg
#   inflating: data/valid/05613.jpg
#   inflating: data/valid/00807.jpg
#   inflating: data/valid/07728.jpg
#   inflating: data/valid/03195.jpg
#   inflating: data/valid/03315.jpg
#   inflating: data/valid/00340.jpg
#   inflating: data/valid/01952.jpg
#   inflating: data/valid/03779.jpg
#   inflating: data/valid/03564.jpg
#   inflating: data/valid/08359.jpg
#   inflating: data/valid/02893.jpg
#   inflating: data/valid/04694.jpg
#   inflating: data/valid/00761.jpg
#   inflating: data/valid/02493.jpg
#   inflating: data/valid/02616.jpg
#   inflating: data/valid/05250.jpg
#   inflating: data/valid/02973.jpg
#   inflating: data/valid/04857.jpg
#   inflating: data/valid/04675.jpg
#   inflating: data/valid/03535.jpg
#   inflating: data/valid/02239.jpg
#   inflating: data/valid/06849.jpg
#   inflating: data/valid/07695.jpg
#   inflating: data/valid/03853.jpg
#   inflating: data/valid/01739.jpg
#   inflating: data/valid/08240.jpg
#   inflating: data/valid/07737.jpg
#   inflating: data/valid/06199.jpg
#   inflating: data/valid/03303.jpg
#   inflating: data/valid/03362.jpg
#   inflating: data/valid/08484.jpg
#   inflating: data/valid/01003.jpg
#   inflating: data/valid/02167.jpg
#   inflating: data/valid/06844.jpg
#   inflating: data/valid/07824.jpg
#   inflating: data/valid/03802.jpg
#   inflating: data/valid/05884.jpg
#   inflating: data/valid/06357.jpg
#   inflating: data/valid/07901.jpg
#   inflating: data/valid/06755.jpg
#   inflating: data/valid/02059.jpg
#   inflating: data/valid/07472.jpg
#   inflating: data/valid/03387.jpg
#   inflating: data/valid/01690.jpg
#   inflating: data/valid/05642.jpg
#   inflating: data/valid/04696.jpg
#   inflating: data/valid/05541.jpg
#   inflating: data/valid/07479.jpg
#   inflating: data/valid/04836.jpg
#   inflating: data/valid/02057.jpg
#   inflating: data/valid/00058.jpg
#   inflating: data/valid/07449.jpg
#   inflating: data/valid/08326.jpg
#   inflating: data/valid/03879.jpg
#   inflating: data/valid/00201.jpg
#   inflating: data/valid/05385.jpg
#   inflating: data/valid/02408.jpg
#   inflating: data/valid/08967.jpg
#   inflating: data/valid/02668.jpg
#   inflating: data/valid/08649.jpg
#   inflating: data/valid/08937.jpg
#   inflating: data/valid/06863.jpg
#   inflating: data/valid/00295.jpg
#   inflating: data/valid/07573.jpg
#   inflating: data/valid/03429.jpg
#   inflating: data/valid/04357.jpg
#   inflating: data/valid/04708.jpg
#   inflating: data/valid/02449.jpg
#   inflating: data/valid/01266.jpg
#   inflating: data/valid/04145.jpg
#   inflating: data/valid/05151.jpg
#   inflating: data/valid/08518.jpg
#   inflating: data/valid/07059.jpg
#   inflating: data/valid/01070.jpg
#   inflating: data/valid/00901.jpg
#   inflating: data/valid/07133.jpg
#   inflating: data/valid/08973.jpg
#   inflating: data/valid/00580.jpg
#   inflating: data/valid/01620.jpg
#   inflating: data/valid/05004.jpg
#   inflating: data/valid/03945.jpg
#   inflating: data/valid/05914.jpg
#   inflating: data/valid/03437.jpg
#   inflating: data/valid/07127.jpg
#   inflating: data/valid/08783.jpg
#   inflating: data/valid/06855.jpg
#   inflating: data/valid/00124.jpg
#   inflating: data/valid/03416.jpg
#   inflating: data/valid/03124.jpg
#   inflating: data/valid/00449.jpg
#   inflating: data/valid/01197.jpg
#   inflating: data/valid/00886.jpg
#   inflating: data/valid/06132.jpg
#   inflating: data/valid/05916.jpg
#   inflating: data/valid/06907.jpg
#   inflating: data/valid/02627.jpg
#   inflating: data/valid/07842.jpg
#   inflating: data/valid/03097.jpg
#   inflating: data/valid/00483.jpg
#   inflating: data/valid/08854.jpg
#   inflating: data/valid/08402.jpg
#   inflating: data/valid/07698.jpg
#   inflating: data/valid/02188.jpg
#   inflating: data/valid/04305.jpg
#   inflating: data/valid/04223.jpg
#   inflating: data/valid/08179.jpg
#   inflating: data/valid/01204.jpg
#   inflating: data/valid/05358.jpg
#   inflating: data/valid/00600.jpg
#   inflating: data/valid/06906.jpg
#   inflating: data/valid/02993.jpg
#   inflating: data/valid/00385.jpg
#   inflating: data/valid/00242.jpg
#   inflating: data/valid/06555.jpg
#   inflating: data/valid/03585.jpg
#   inflating: data/valid/06111.jpg
#   inflating: data/valid/04895.jpg
#   inflating: data/valid/07098.jpg
#   inflating: data/valid/02170.jpg
#   inflating: data/valid/labels.csv
#   inflating: data/valid/00266.jpg
#   inflating: data/valid/01120.jpg
#   inflating: data/valid/08519.jpg
#   inflating: data/valid/03930.jpg
#   inflating: data/valid/05490.jpg
#   inflating: data/valid/07809.jpg
#   inflating: data/valid/04769.jpg
#   inflating: data/valid/04419.jpg
#   inflating: data/valid/02606.jpg
#   inflating: data/valid/07109.jpg
#   inflating: data/valid/08426.jpg
#   inflating: data/valid/06500.jpg
#   inflating: data/valid/07752.jpg
#   inflating: data/valid/06397.jpg
#   inflating: data/valid/07370.jpg
#   inflating: data/valid/04324.jpg
#   inflating: data/valid/04777.jpg
#   inflating: data/valid/06342.jpg
#   inflating: data/valid/00476.jpg
#   inflating: data/valid/07537.jpg
#   inflating: data/valid/00414.jpg
#   inflating: data/valid/02003.jpg
#   inflating: data/valid/01977.jpg
#   inflating: data/valid/05457.jpg
#   inflating: data/valid/00065.jpg
#   inflating: data/valid/08495.jpg
#   inflating: data/valid/07108.jpg
#   inflating: data/valid/07312.jpg
#   inflating: data/valid/08250.jpg
#   inflating: data/valid/08091.jpg
#   inflating: data/valid/04219.jpg
#   inflating: data/valid/03845.jpg
#   inflating: data/valid/01369.jpg
#   inflating: data/valid/04792.jpg
#   inflating: data/valid/02653.jpg
#   inflating: data/valid/02316.jpg
#   inflating: data/valid/03540.jpg
#   inflating: data/valid/06985.jpg
#   inflating: data/valid/00487.jpg
#   inflating: data/valid/03398.jpg
#   inflating: data/valid/05598.jpg
#   inflating: data/valid/00641.jpg
#   inflating: data/valid/04243.jpg
#   inflating: data/valid/07193.jpg
#   inflating: data/valid/06705.jpg
#   inflating: data/valid/00694.jpg
#   inflating: data/valid/07716.jpg
#   inflating: data/valid/00218.jpg
#   inflating: data/valid/05166.jpg
#   inflating: data/valid/04256.jpg
#   inflating: data/valid/06784.jpg
#   inflating: data/valid/05308.jpg
#   inflating: data/valid/06302.jpg
#   inflating: data/valid/05723.jpg
#   inflating: data/valid/02027.jpg
#   inflating: data/valid/04001.jpg
#   inflating: data/valid/05967.jpg
#   inflating: data/valid/02442.jpg
#   inflating: data/valid/00412.jpg
#   inflating: data/valid/05946.jpg
#   inflating: data/valid/01060.jpg
#   inflating: data/valid/05907.jpg
#   inflating: data/valid/08956.jpg
#   inflating: data/valid/05526.jpg
#   inflating: data/valid/08886.jpg
#   inflating: data/valid/06726.jpg
#   inflating: data/valid/02573.jpg
#   inflating: data/valid/01601.jpg
#   inflating: data/valid/02420.jpg
#   inflating: data/valid/04668.jpg
#   inflating: data/valid/00993.jpg
#   inflating: data/valid/05529.jpg
#   inflating: data/valid/07734.jpg
#   inflating: data/valid/02070.jpg
#   inflating: data/valid/01875.jpg
#   inflating: data/valid/06882.jpg
#   inflating: data/valid/00494.jpg
#   inflating: data/valid/01751.jpg
#   inflating: data/valid/00620.jpg
#   inflating: data/valid/02299.jpg
#   inflating: data/valid/04678.jpg
#   inflating: data/valid/04456.jpg
#   inflating: data/valid/08483.jpg
#   inflating: data/valid/07157.jpg
#   inflating: data/valid/00465.jpg
#   inflating: data/valid/08972.jpg
#   inflating: data/valid/05156.jpg
#   inflating: data/valid/01648.jpg
#   inflating: data/valid/00515.jpg
#   inflating: data/valid/06584.jpg
#   inflating: data/valid/07910.jpg
#   inflating: data/valid/04216.jpg
#   inflating: data/valid/05879.jpg
#   inflating: data/valid/00250.jpg
#   inflating: data/valid/01670.jpg
#   inflating: data/valid/06025.jpg
#   inflating: data/valid/03570.jpg
#   inflating: data/valid/07028.jpg
#   inflating: data/valid/07675.jpg
#   inflating: data/valid/08777.jpg
#   inflating: data/valid/02593.jpg
#   inflating: data/valid/01591.jpg
#   inflating: data/valid/04765.jpg
#   inflating: data/valid/02002.jpg
#   inflating: data/valid/01452.jpg
#   inflating: data/valid/04566.jpg
#   inflating: data/valid/08114.jpg
#   inflating: data/valid/05701.jpg
#   inflating: data/valid/08257.jpg
#   inflating: data/valid/05260.jpg
#   inflating: data/valid/04073.jpg
#   inflating: data/valid/05962.jpg
#   inflating: data/valid/06264.jpg
#   inflating: data/valid/06718.jpg
#   inflating: data/valid/02473.jpg
#   inflating: data/valid/04203.jpg
#   inflating: data/valid/03992.jpg
#   inflating: data/valid/07419.jpg
#   inflating: data/valid/02750.jpg
#   inflating: data/valid/02976.jpg
#   inflating: data/valid/03332.jpg
#   inflating: data/valid/06779.jpg
#   inflating: data/valid/01797.jpg
#   inflating: data/valid/03040.jpg
#   inflating: data/valid/03669.jpg
#   inflating: data/valid/08377.jpg
#   inflating: data/valid/04381.jpg
#   inflating: data/valid/05845.jpg
#   inflating: data/valid/04510.jpg
#   inflating: data/valid/03929.jpg
#   inflating: data/valid/01962.jpg
#   inflating: data/valid/03090.jpg
#   inflating: data/valid/03746.jpg
#   inflating: data/valid/03691.jpg
#   inflating: data/valid/00417.jpg
#   inflating: data/valid/06203.jpg
#   inflating: data/valid/01932.jpg
#   inflating: data/valid/05876.jpg
#   inflating: data/valid/03974.jpg
#   inflating: data/valid/08215.jpg
#   inflating: data/valid/00866.jpg
#   inflating: data/valid/03898.jpg
#   inflating: data/valid/07085.jpg
#   inflating: data/valid/06970.jpg
#   inflating: data/valid/03632.jpg
#   inflating: data/valid/00916.jpg
#   inflating: data/valid/05158.jpg
#   inflating: data/valid/06493.jpg
#   inflating: data/valid/04630.jpg
#   inflating: data/valid/00246.jpg
#   inflating: data/valid/08543.jpg
#   inflating: data/valid/08277.jpg
#   inflating: data/valid/01101.jpg
#   inflating: data/valid/05149.jpg
#   inflating: data/valid/06379.jpg
#   inflating: data/valid/08738.jpg
#   inflating: data/valid/03176.jpg
#   inflating: data/valid/03257.jpg
#   inflating: data/valid/05714.jpg
#   inflating: data/valid/06151.jpg
#   inflating: data/valid/02137.jpg
#   inflating: data/valid/02193.jpg
#   inflating: data/valid/06022.jpg
#   inflating: data/valid/08583.jpg
#   inflating: data/valid/05765.jpg
#   inflating: data/valid/00675.jpg
#   inflating: data/valid/06617.jpg
#   inflating: data/valid/02291.jpg
#   inflating: data/valid/01363.jpg
#   inflating: data/valid/03659.jpg
#   inflating: data/valid/08217.jpg
#   inflating: data/valid/06474.jpg
#   inflating: data/valid/08472.jpg
#   inflating: data/valid/08839.jpg
#   inflating: data/valid/07907.jpg
#   inflating: data/valid/06507.jpg
#   inflating: data/valid/00806.jpg
#   inflating: data/valid/04179.jpg
#   inflating: data/valid/03420.jpg
#   inflating: data/valid/00589.jpg
#   inflating: data/valid/02427.jpg
#   inflating: data/valid/00159.jpg
#   inflating: data/valid/06441.jpg
#   inflating: data/valid/00841.jpg
#   inflating: data/valid/03290.jpg
#   inflating: data/valid/02263.jpg
#   inflating: data/valid/02996.jpg
#   inflating: data/valid/07922.jpg
#   inflating: data/valid/03373.jpg
#   inflating: data/valid/06952.jpg
#   inflating: data/valid/05679.jpg
#   inflating: data/valid/08423.jpg
#   inflating: data/valid/07632.jpg
#   inflating: data/valid/02834.jpg
#   inflating: data/valid/08812.jpg
#   inflating: data/valid/00034.jpg
#   inflating: data/valid/06480.jpg
#   inflating: data/valid/00209.jpg
#   inflating: data/valid/08704.jpg
#   inflating: data/valid/01184.jpg
#   inflating: data/valid/00530.jpg
#   inflating: data/valid/07186.jpg
#   inflating: data/valid/04737.jpg
#   inflating: data/valid/05935.jpg
#   inflating: data/valid/04323.jpg
#   inflating: data/valid/03382.jpg
#   inflating: data/valid/06075.jpg
#   inflating: data/valid/00626.jpg
#   inflating: data/valid/00968.jpg
#   inflating: data/valid/08525.jpg
#   inflating: data/valid/05363.jpg
#   inflating: data/valid/00565.jpg
#   inflating: data/valid/01185.jpg
#   inflating: data/valid/08877.jpg
#   inflating: data/valid/06370.jpg
#   inflating: data/valid/00205.jpg
#   inflating: data/valid/05875.jpg
#   inflating: data/valid/08800.jpg
#   inflating: data/valid/03261.jpg
#   inflating: data/valid/02234.jpg
#   inflating: data/valid/07560.jpg
#   inflating: data/valid/02339.jpg
#   inflating: data/valid/08813.jpg
#   inflating: data/valid/06083.jpg
#   inflating: data/valid/06804.jpg
#   inflating: data/valid/07412.jpg
#   inflating: data/valid/05612.jpg
#   inflating: data/valid/04608.jpg
#   inflating: data/valid/03710.jpg
#   inflating: data/valid/03883.jpg
#   inflating: data/valid/03443.jpg
#   inflating: data/valid/05635.jpg
#   inflating: data/valid/08910.jpg
#   inflating: data/valid/07237.jpg
#   inflating: data/valid/05764.jpg
#   inflating: data/valid/05376.jpg
#   inflating: data/valid/01501.jpg
#   inflating: data/valid/06453.jpg
#   inflating: data/valid/08201.jpg
#   inflating: data/valid/06478.jpg
#   inflating: data/valid/04108.jpg
#   inflating: data/valid/03307.jpg
#   inflating: data/valid/01457.jpg
#   inflating: data/valid/00723.jpg
#   inflating: data/valid/03140.jpg
#   inflating: data/valid/05677.jpg
#   inflating: data/valid/03288.jpg
#   inflating: data/valid/05904.jpg
#   inflating: data/valid/07223.jpg
#   inflating: data/valid/08917.jpg
#   inflating: data/valid/07270.jpg
#   inflating: data/valid/07189.jpg
#   inflating: data/valid/02944.jpg
#   inflating: data/valid/03130.jpg
#   inflating: data/valid/04618.jpg
#   inflating: data/valid/02579.jpg
#   inflating: data/valid/08156.jpg
#   inflating: data/valid/05830.jpg
#   inflating: data/valid/05687.jpg
#   inflating: data/valid/07605.jpg
#   inflating: data/valid/08184.jpg
#   inflating: data/valid/00989.jpg
#   inflating: data/valid/04865.jpg
#   inflating: data/valid/02597.jpg
#   inflating: data/valid/02010.jpg
#   inflating: data/valid/06467.jpg
#   inflating: data/valid/01849.jpg
#   inflating: data/valid/01395.jpg
#   inflating: data/valid/02811.jpg
#   inflating: data/valid/00061.jpg
#   inflating: data/valid/05063.jpg
#   inflating: data/valid/06205.jpg
#   inflating: data/valid/05231.jpg
#   inflating: data/valid/04004.jpg
#   inflating: data/valid/04083.jpg
#   inflating: data/valid/05189.jpg
#   inflating: data/valid/07113.jpg
#   inflating: data/valid/03663.jpg
#   inflating: data/valid/01050.jpg
#   inflating: data/valid/02647.jpg
#   inflating: data/valid/08197.jpg
#   inflating: data/valid/05835.jpg
#   inflating: data/valid/01968.jpg
#   inflating: data/valid/06131.jpg
#   inflating: data/valid/00897.jpg
#   inflating: data/valid/00264.jpg
#   inflating: data/valid/01921.jpg
#   inflating: data/valid/04309.jpg
#   inflating: data/valid/06665.jpg
#   inflating: data/valid/00574.jpg
#   inflating: data/valid/01872.jpg
#   inflating: data/valid/04778.jpg
#   inflating: data/valid/08544.jpg
#   inflating: data/valid/08945.jpg

# %% [markdown]
# ## Defining Torch Dataset

# %%
class SuperTuxDataset(Dataset):
    def __init__(self, image_path,data_transforms=None):
        """
        Your code here
        Hint: Use the python csv library to parse labels.csv
        """
        raise NotImplementedError('SuperTuxDataset.__init__')

    def __len__(self):
        """
        Your code here
        """
        raise NotImplementedError('SuperTuxDataset.__len__')

    def __getitem__(self, idx):
        """
        Your code here
        return a tuple: img, label
        """
        raise NotImplementedError('SuperTuxDataset.__getitem__')

# %% [markdown]
# The following utility visualizes the data, optionally, as a sanity check for your implementation of the dataset class. Call visualize_data() after setting the correct variables inside this code snippet.

# %%
def visualize_data():

    Path_to_your_data= ' '
    dataset = SuperTuxDataset(image_path=Path_to_your_data)

    f, axes = plt.subplots(3, len(LABEL_NAMES))

    counts = [0]*len(LABEL_NAMES)

    for img, label in dataset:
        c = counts[label]

        if c < 3:
            ax = axes[c][label]
            ax.imshow(img.permute(1, 2, 0).numpy())
            ax.axis('off')
            ax.set_title(LABEL_[label])
            counts[label] += 1
        
        if sum(counts) >= 3 * len(LABEL_NAMES):
            break

    plt.show()

# %% [markdown]
# ## Defining Model Architecture and Loss

# %%
class ClassificationLoss(torch.nn.Module):
    def forward(self, input, target):
        """
        Your code here
        Compute mean(-log(softmax(input)_label))
        @input:  torch.Tensor((B,C)), where B = batch size, C = number of classes
        @target: torch.Tensor((B,), dtype=torch.int64)
        @return:  torch.Tensor((,))
        Hint: Don't be too fancy, this is a one-liner
        """
        raise NotImplementedError('ClassificationLoss.forward')


class CNNClassifier(torch.nn.Module):
    def __init__(self):
        """
        Your code here
        """
        raise NotImplementedError('CNNClassifier.__init__')

    def forward(self, x):
        """
        Your code here
        @x: torch.Tensor((B,3,64,64))
        @return: torch.Tensor((B,6))
        """
        raise NotImplementedError('CNNClassifier.forward')

# %%
from torch import save
from torch import load
from os import path

def save_model(model):
    if isinstance(model, CNNClassifier):
        return save(model.state_dict(), path.join(path.dirname(path.abspath(__file__)), 'cnn.th'))
    
    raise ValueError("model type '%s' not supported!"%str(type(model)))


def load_model():
    r = CNNClassifier()
    r.load_state_dict(load(path.join(path.dirname(path.abspath(__file__)), 'cnn.th'), map_location='cpu'))
    return r

# %% [markdown]
# ## Tensorboard logging

# %%
def test_logging(train_logger, valid_logger):

    """
    Your code here.
    Finish logging the dummy loss and accuracy
    Log the loss every iteration, the accuracy only after each epoch
    Make sure to set global_step correctly, for epoch=0, iteration=0: global_step=0
    Call the loss 'loss', and accuracy 'accuracy' (no slash or other namespace)
    """

    # This is a strongly simplified training loop
    for epoch in range(10):
        torch.manual_seed(epoch)
        for iteration in range(20):
            dummy_train_loss = 0.9**(epoch+iteration/20.)
            dummy_train_accuracy = epoch/10. + torch.randn(10)
            raise NotImplementedError('Log the training loss')
        raise NotImplementedError('Log the training accuracy')
        torch.manual_seed(epoch)
        for iteration in range(10):
            dummy_validation_accuracy = epoch / 10. + torch.randn(10)
        raise NotImplementedError('Log the validation accuracy')

# %% [markdown]
# After implementing `test_logging()`, call it below. This should produce some plots on your tensorboard.

# %%
# %load_ext tensorboard

# %%
# %reload_ext tensorboard

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

from torch.utils.tensorboard import SummaryWriter
ROOT_LOG_DIR = './logdir'

# %%
# %tensorboard --logdir {ROOT_LOG_DIR} #Launch tensorboard

# %%
train_logger = tb.SummaryWriter(path.join('./logdir', 'train'))
valid_logger = tb.SummaryWriter(path.join('./logdir', 'test'))
test_logging(train_logger, valid_logger)

# %% [markdown]
# **Training and evaluation utility functions**
#
# Here are some implementations of useful functions for training and evaluating your models. Read these carefully. You may need to make some obvious edits before these will work.

# %%
def accuracy(outputs, labels):
    outputs_idx = outputs.max(1)[1].type_as(labels)
    return outputs_idx.eq(labels).float().mean()

def predict(model, inputs, device='cpu'):
    inputs = inputs.to(device)
    logits = model(inputs)
    return F.softmax(logits, -1)
    def draw_bar(axis, preds, labels=None):
    y_pos = np.arange(6)
    axis.barh(y_pos, preds, align='center', alpha=0.5)
    axis.set_xticks(np.linspace(0, 1, 10))
    
    if labels:
        axis.set_yticks(y_pos)
        axis.set_yticklabels(labels)
    else:
        axis.get_yaxis().set_visible(False)
    
    axis.get_xaxis().set_visible(False)

def visualize_predictions():
  
    model = load_model()
    model.eval()

    validation_image_path='' #enter the path 

    dataset = SuperTuxDataset(image_path=validation_image_path)

    f, axes = plt.subplots(2, 6)

    idxes = np.random.randint(0, len(dataset), size=6)

    for i, idx in enumerate(idxes):
        img, label = dataset[idx]
        preds = predict(model, img[None], device='cpu').detach().cpu().numpy()

        axes[0, i].imshow(TF.to_pil_image(img))
        axes[0, i].axis('off')
        draw_bar(axes[1, i], preds[0], LABEL_ if i == 0 else None)

    plt.show()

# %% [markdown]
# ## Training models
#
# The `load_data` utility below uses your implementation of the dataset class above to provide a helper function that might be useful when you train your models. You won't need to change anything inside this function.

# %%
def load_data(dataset_path, data_transforms=None, num_workers=0, batch_size=128):
    dataset = SuperTuxDataset(dataset_path,data_transforms)
    return DataLoader(dataset, num_workers=num_workers, batch_size=batch_size, shuffle=True)

# %% [markdown]
# But you *will* need to implement `train()`, which takes an `args` object, that could have arbitrary arguments inside. We won't test your train function directly, but will instead evaluate the model it produces as output. To call `train`, you have to first create an args object, and add various attributes to it, as shown below:

# %%
class Args(object):
  pass

args = Args();
# Add attributes to args here, such as:
# args.learning_rate = 0.0001
# args.log_dir = './my_tensorboard_log_directory'

# %% [markdown]
# Then implement `train`. Follow the instructions in the assignment.

# %%
def train(args):
    """
    Your code here
    """
    model = CNNClassifier()
    if args.log_dir is not None:
        train_logger = tb.SummaryWriter(path.join(args.log_dir, 'train'))
        valid_logger = tb.SummaryWriter(path.join(args.log_dir, 'valid'))

    raise NotImplementedError('train')

    save_model(model)

# %% [markdown]
# Now, you can call `train` with `train(args)`, where `args` contains your various favorite settings of hyperparameters and other arguments that your implementation of `train` needs.
#
#
# Afterwards, you can call `predict()' and `visualize_predictions()' to evaluate your model.
